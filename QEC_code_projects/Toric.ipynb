# %%
import numpy as np 
import stim 
import pymatching 

circuit = stim.Circuit.generated(
        'surface_code: rotated_memory_x',
        distance = 5 ,
        round = 5 ,
        after_clifford_depolarization = 0.005
 )
model = circuit.detector_error_model(decompose_errors = True)
matching = pymatching.Matching.from_detector_error_model(model)


print(circuit)
print(stim._version_)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 import stim
# ----> 3 import pymatching
#       5 circuit = stim.Circuit.generated(
#       6         'surface_code: rotated_memory_x',
#       7         distance = 5 ,
#       8         round = 5 ,
#       9         after_clifford_depolarization = 0.005
#      10  )
#      11 model = circuit.detector_error_model(decompose_errors = True)
#
# ModuleNotFoundError: No module named 'pymatching'
